# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
#%%
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df = pd.read_csv(r"datadata.txt")
df
# Out:
#    X    y
# 0   1    2
# 1   2    4
# 2   3    6
# 3   4    8

# %%
dataf = df.copy()

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,:-1]

# %%
print(x)
print(y)
# Out:
#    X
# 0   1
# 1   2
# 2   3
# 3   4
#    X
# 0   1
# 1   2
# 2   3
# 3   4

# %%
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
I = 1
lasso = Ridge(alpha=1)
lasso.fit(x,y)
# Out:
# Ridge(alpha=1)

# %%
lasso_co = lasso.coef_
lasso_co
# Out:
# array([[0.83333333]])

# %%
lassso_intercept = lasso.intercept_
lassso_intercept
# Out:
# array([0.41666667])

# %%
x_test = [1,2,3,4]
y_pred = lasso.predict(pd.DataFrame(x_test))
y_pred
# Out:
# array([[1.25      ],
#        [2.08333333],
#        [2.91666667],
#        [3.75      ]])

# %%
plt.figure(figsize=(12,6) , dpi = 90)
plt.plot(x_test,y_pred , c ='r' , linewidth = 2)
plt.scatter(x,y)
plt.ylim(ymin = 0 , ymax = 9)
plt.xlim(xmin = 0 , xmax = 7)

plt.text(x_test[-1],y_pred[-1] , ' y = '   +    str('%.2f' %lasso_co)  + ' * X +'  +  str('%.2f' %lassso_intercept)
                                                   +  '  For \u03BB or  \u03b1 = ' +    str(I)  ,   fontsize = 12)
plt.title('Lasso Regression')
plt.show()

# %%
t= (77,"ali")
print(t*2)
# Out:
# (77, 'ali', 77, 'ali')
